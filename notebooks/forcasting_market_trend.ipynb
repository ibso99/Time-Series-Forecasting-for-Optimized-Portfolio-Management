# %% [markdown]
# ### Import Libraries

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.forecast import *

# %%
TSLA_analyzer = MarketTrendAnalyzer(model_path= "../Notebooks/TSLA_lstm_model.pth",scaler_path= "../Notebooks/TSLA_scaler.pkl", historical_data_path="../data/TSLA_proccessed_data.csv",
                               seq_length=30,  # Use the last 30 days of data
    forecast_periods=10  # Forecast for the next 10 days
)
SPY_analyzer = MarketTrendAnalyzer(model_path= "../Notebooks/SPY_lstm_model.pth",scaler_path= "../Notebooks/SPY_scaler.pkl", historical_data_path="../data/SPY_proccessed_data.csv",
                               seq_length=30,  # Use the last 30 days of data
    forecast_periods=10  # Forecast for the next 10 days
)
BND_analyzer = MarketTrendAnalyzer(model_path= "../Notebooks/BND_lstm_model.pth",scaler_path= "../Notebooks/BND_scaler.pkl", historical_data_path="../data/BND_proccessed_data.csv",
                               seq_length=30,  # Use the last 30 days of data
    forecast_periods=10  # Forecast for the next 10 days
)
# Out:
# c:\Users\elbet\OneDrive\Desktop\Ten\week-11\Time-Series-Forecasting-for-Portfolio-Management-Optimization-main\scripts\forecast.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=self.device))
# c:\Users\elbet\OneDrive\Desktop\Ten\week-11\Time-Series-Forecasting-for-Portfolio-Management-Optimization-main\scripts\forecast.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=self.device))
# c:\Users\elbet\OneDrive\Desktop\Ten\week-11\Time-Series-Forecasting-for-Portfolio-Management-Optimization-main\scripts\forecast.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=self.device))

# %%
TSLA_forecast_df = TSLA_analyzer.generate_forecast(save_path="../data/TSLA_forcasted_data.csv")
SPY_forecast_df = SPY_analyzer.generate_forecast(save_path="../data/SPY_forcasted_data.csv")
BND_forecast_df = BND_analyzer.generate_forecast(save_path="../data/BND_forcasted_data.csv")
# Out:
# Forecast saved to ../data/TSLA_forcasted_data.csv
# Forecast saved to ../data/SPY_forcasted_data.csv
# Forecast saved to ../data/BND_forcasted_data.csv

# %%
TSLA_analyzer.plot_forecast()
SPY_analyzer.plot_forecast()
BND_analyzer.plot_forecast()

# %%
TSLA_analyzer.analyze_trends()
# Out:
# {'Trend': 'Downward',
#  'Trend_Magnitude': 15,
#  'Volatility': 0.02,
#  'Max_Price': 5.3841657638549805,
#  'Min_Price': 2.301384925842285,
#  'Price_Range': 3.0827808380126953}

# %%
SPY_analyzer.analyze_trends()
# Out:
# {'Trend': 'Downward',
#  'Trend_Magnitude': 15,
#  'Volatility': 0.017154350944465702,
#  'Max_Price': 4.0131964683532715,
#  'Min_Price': 2.336205244064331,
#  'Price_Range': 1.6769912242889404}

# %%
BND_analyzer.analyze_trends()
# Out:
# {'Trend': 'Downward',
#  'Trend_Magnitude': 15,
#  'Volatility': 0.02,
#  'Max_Price': 4.56825590133667,
#  'Min_Price': 3.0759506225585938,
#  'Price_Range': 1.4923052787780762}

# %%
TSLA_analyzer.generate_report()
# Out:
# '\n        Market Trend Analysis Report\n        ============================\n\n        1. Overall Trend Analysis:\n        -------------------------\n        Direction: Downward\n        Trend Magnitude: 15.00\n\n        2. Price Projections:\n        --------------------\n        Forecasted Maximum Price: $5.38\n        Forecasted Minimum Price: $2.30\n        Expected Price Range: $3.08\n\n        3. Volatility Analysis:\n        ----------------------\n        Forecasted Volatility: 2.00%\n\n        4. Market Opportunities and Risks:\n        -------------------------------\n        Main Opportunities:\n        * Potential buying opportunities during dips\n        * Stable price movement expected\n\n        Main Risks:\n        * Limited price movement\n        * Potential for significant drawdowns\n\n        5. Investment Implications:\n        ------------------------\n        Suitable for longer-term position holding\n        '

# %%
SPY_analyzer.generate_report()
# Out:
# '\n        Market Trend Analysis Report\n        ============================\n\n        1. Overall Trend Analysis:\n        -------------------------\n        Direction: Downward\n        Trend Magnitude: 15.00\n\n        2. Price Projections:\n        --------------------\n        Forecasted Maximum Price: $4.01\n        Forecasted Minimum Price: $2.34\n        Expected Price Range: $1.68\n\n        3. Volatility Analysis:\n        ----------------------\n        Forecasted Volatility: 1.72%\n\n        4. Market Opportunities and Risks:\n        -------------------------------\n        Main Opportunities:\n        * Potential buying opportunities during dips\n        * Stable price movement expected\n\n        Main Risks:\n        * Limited price movement\n        * Potential for significant drawdowns\n\n        5. Investment Implications:\n        ------------------------\n        Suitable for longer-term position holding\n        '

# %%
BND_analyzer.generate_report()
# Out:
# '\n        Market Trend Analysis Report\n        ============================\n\n        1. Overall Trend Analysis:\n        -------------------------\n        Direction: Downward\n        Trend Magnitude: 15.00\n\n        2. Price Projections:\n        --------------------\n        Forecasted Maximum Price: $4.57\n        Forecasted Minimum Price: $3.08\n        Expected Price Range: $1.49\n\n        3. Volatility Analysis:\n        ----------------------\n        Forecasted Volatility: 2.00%\n\n        4. Market Opportunities and Risks:\n        -------------------------------\n        Main Opportunities:\n        * Potential buying opportunities during dips\n        * Stable price movement expected\n\n        Main Risks:\n        * Limited price movement\n        * Potential for significant drawdowns\n\n        5. Investment Implications:\n        ------------------------\n        Suitable for longer-term position holding\n        '
