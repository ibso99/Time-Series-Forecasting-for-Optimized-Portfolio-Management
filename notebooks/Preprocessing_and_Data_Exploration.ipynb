# %% [markdown]
# # 10 Academy: Artificial Intelligence Mastery
# ## Time Series Forecasting for Portfolio Management Optimization
# ### Data fetching from yahoo finance and Data Exploration
# Ethel.C

# %%
import sys

# Define directory paths
scripts_dir = r'E:\DS+ML\AIM3\Week.11\Time-Series-Forecasting-for-Optimized-Portfolio-Management\scripts'
src_dir = r'E:\DS+ML\AIM3\Week.11\Time-Series-Forecasting-for-Optimized-Portfolio-Management\src'
input_dir = r"E:\DS+ML\AIM3\Week.11\Time-Series-Forecasting-for-Optimized-Portfolio-Management\financial_data"
output_dir = r"E:\DS+ML\AIM3\Week.11\Time-Series-Forecasting-for-Optimized-Portfolio-Management\cleaned_data"

# Add paths to sys.path
if scripts_dir not in sys.path:
    sys.path.append(scripts_dir)
if src_dir not in sys.path:
    sys.path.append(src_dir)

# Importing functions from clean_data.py
from clean_data import main #load_data, check_statistics, check_data_types, handle_missing_values, normalize_data, save_cleaned_data
# Define input and output directories
from eda import load_data_from_directory,perform_eda

# %% [markdown]
# ### Fetching Data and Processing

# %%
main(input_dir, output_dir)
# Out:
# Before Normalization - BND_historical:
# Basic Statistics for 'Close' and 'Volume':
#              Close        Volume
# count  2536.000000  2.536000e+03
# mean     69.289451  4.233200e+06
# std       4.791201  2.795532e+06
# min      61.860882  0.000000e+00
# 25%      65.569477  2.059400e+06
# 50%      68.329914  3.805900e+06
# 75%      72.879097  5.626450e+06
# max      78.823250  3.193720e+07
# Data types:
# Close     float64
# Volume    float64
# dtype: object
#
# After Normalization:
# Basic Statistics for 'Close' and 'Volume':
#        Close_Normalized  Volume_Normalized
# count       2536.000000        2536.000000
# mean           0.437944           0.132548
# std            0.282461           0.087532
# min            0.000000           0.000000
# 25%            0.218637           0.064483
# 50%            0.381376           0.119168
# 75%            0.649568           0.176172
# max            1.000000           1.000000
# Data types:
# Close_Normalized     float64
# ...

# %% [markdown]
# ### Data Exploration and Explanatory Data Analysis

# %%
# Load the data
cleaned_data = load_data_from_directory(output_dir)

# Perform EDA
perform_eda(cleaned_data, rolling_window=20)  # You can change rolling_window as needed
# Out:
# Loaded data for BND
# Loaded data for SPY
# Loaded data for TSLA
# Loaded 3 datasets
# VaR at 95% confidence for BND: -0.48%
# VaR at 99% confidence for BND: -0.88%
# Sharpe Ratio for BND: 0.01
# High return days for BND:
# Empty DataFrame
# Columns: [Daily Return]
# Index: []
# Low return days for BND:
# Empty DataFrame
# Columns: [Daily Return]
# Index: []
# VaR at 95% confidence for SPY: -1.68%
# VaR at 99% confidence for SPY: -3.23%
# Sharpe Ratio for SPY: 0.03
# High return days for SPY:
# Empty DataFrame
# Columns: [Daily Return]
# Index: []
# Low return days for SPY:
#             Daily Return
# Date
# 2015-01-02    -45.393676
# 2020-03-16    -10.942380
# VaR at 95% confidence for TSLA: -5.18%
# VaR at 99% confidence for TSLA: -9.06%
# Sharpe Ratio for TSLA: 0.04
# High return days for TSLA:
#             Daily Return
# Date
# 2015-11-04     11.173506
# 2018-08-02     16.188013
# 2018-08-07     10.988624
# 2018-10-01     17.347133
# 2018-10-23     12.718905
# ...
